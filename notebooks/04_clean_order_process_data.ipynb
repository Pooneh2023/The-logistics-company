# %%
import pandas as pd
import numpy as np

# %%
Clean_internData_study = pd.read_excel('../data/raw/Muesli Project raw data.xlsx',sheet_name='InternData_study')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Clean_internData_study = pd.read_excel('../data/raw/Muesli Project raw data.xlsx',sheet_name='InternData_study')
#
# File ~/Desktop/Internship/Projects-/The-logistics-company/.venv/lib/python3.12/site-packages/pandas/io/excel/_base.py:494, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     488     raise ValueError(
#     489         "Engine should not be specified when passing "
#     490         "an ExcelFile - ExcelFile already has the engine set"
#     491     )
#     493 try:
# --> 494     data = io.parse(
#     495         sheet_name=sheet_name,
#     496         header=header,
#     497         names=names,
#     498         index_col=index_col,
#     499         usecols=usecols,
#     500         dtype=dtype,
#     501         converters=converters,
#     502         true_values=true_values,
#     503         false_values=false_values,
#     504         skiprows=skiprows,
#     505         nrows=nrows,
#     506         na_values=na_values,
#     507         keep_default_na=keep_default_na,
#     508         na_filter=na_filter,
#     509         verbose=verbose,
#     510         parse_dates=parse_dates,
#     511         date_format=date_format,
#     512         thousands=thousands,
#     513         decimal=decimal,
#     514         comment=comment,
#     515         skipfooter=skipfooter,
#     516         dtype_backend=dtype_backend,
#     517     )
#     518 finally:
#     519     # make sure to close opened file handles
#     520     if should_close:
#
# File ~/Desktop/Internship/Projects-/The-logistics-company/.venv/lib/python3.12/site-packages/pandas/io/excel/_base.py:1780, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    1630 def parse(
#    1631     self,
#    1632     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)   1649     **kwds,
#    1650 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1651     """
#    1652     Parse specified sheet(s) into a DataFrame.
#    1653
#    (...)   1778     >>> file.parse()  # doctest: +SKIP
#    1779     """
# -> 1780     return self._reader.parse(
#    1781         sheet_name=sheet_name,
#    1782         header=header,
#    1783         names=names,
#    1784         index_col=index_col,
#    1785         usecols=usecols,
#    1786         converters=converters,
#    1787         true_values=true_values,
#    1788         false_values=false_values,
#    1789         skiprows=skiprows,
#    1790         nrows=nrows,
#    1791         na_values=na_values,
#    1792         parse_dates=parse_dates,
#    1793         date_format=date_format,
#    1794         thousands=thousands,
#    1795         comment=comment,
#    1796         skipfooter=skipfooter,
#    1797         dtype_backend=dtype_backend,
#    1798         **kwds,
#    1799     )
#
# File ~/Desktop/Internship/Projects-/The-logistics-company/.venv/lib/python3.12/site-packages/pandas/io/excel/_base.py:753, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     750     print(f"Reading sheet {asheetname}")
#     752 if isinstance(asheetname, str):
# --> 753     sheet = self.get_sheet_by_name(asheetname)
#     754 else:  # assume an integer if not a string
#     755     sheet = self.get_sheet_by_index(asheetname)
#
# File ~/Desktop/Internship/Projects-/The-logistics-company/.venv/lib/python3.12/site-packages/pandas/io/excel/_openpyxl.py:589, in OpenpyxlReader.get_sheet_by_name(self, name)
#     588 def get_sheet_by_name(self, name: str):
# --> 589     self.raise_if_bad_sheet_by_name(name)
#     590     return self.book[name]
#
# File ~/Desktop/Internship/Projects-/The-logistics-company/.venv/lib/python3.12/site-packages/pandas/io/excel/_base.py:605, in BaseExcelReader.raise_if_bad_sheet_by_name(self, name)
#     603 def raise_if_bad_sheet_by_name(self, name: str) -> None:
#     604     if name not in self.sheet_names:
# --> 605         raise ValueError(f"Worksheet named '{name}' not found")
#
# ValueError: Worksheet named 'InternData_study' not found

# %%
order_process_data.head(4)
# Out:
#    Row ID        Order ID Order Date On Truck Scan Date            Ship Mode
# 0    3074  CA-2019-125206 2019-01-03         2019-01-07              Express
# 1    4919  CA-2019-160304 2019-01-02         2019-01-09  Standard Processing
# 2    4920  CA-2019-160304 2019-01-02         2019-01-09  Standard Processing
# 3    8604  US-2019-116365 2019-01-03         2019-01-09  Standard Processing

# %%
order_process_data.isna().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# On Truck Scan Date    0
# Ship Mode             0
# dtype: int64

# %%
order_process_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
order_process_data.dtypes
# Out:
# Row ID                         int64
# Order ID                         str
# Order Date            datetime64[us]
# On Truck Scan Date    datetime64[us]
# Ship Mode                        str
# dtype: object

# %%
order_process_data["Ship Mode"].unique()
# Out:
# <StringArray>
# ['Express', 'Standard Processing']
# Length: 2, dtype: str

# %%
order_process_data["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Standard Processing    4596
# Express                1303
# Name: count, dtype: int64

# %%
order_process_data['First_class']= np.where(
    order_process_data["Ship Mode"]=='Express', 1 , 0)

# %%
order_process_data.tail(4)
# Out:
#       Row ID        Order ID Order Date On Truck Scan Date  \
# 5895     909  CA-2020-143259 2020-12-30         2021-01-06
# 5896    1297  CA-2020-115427 2020-12-30         2021-01-06
# 5897    1298  CA-2020-115427 2020-12-30         2021-01-06
# 5898    5092  CA-2020-156720 2020-12-30         2021-01-06
#
#                 Ship Mode  First_class
# 5895  Standard Processing            0
# 5896  Standard Processing            0
# 5897  Standard Processing            0
# 5898  Standard Processing            0

# %%
order_process_data['Day_name_On_Truck_scan']=order_process_data['On Truck Scan Date'].dt.day_name()

# %%
order_process_data['Day_name_On_Truck_scan'].unique()
# Out:
# <StringArray>
# ['Monday', 'Wednesday', 'Friday', 'Tuesday', 'Thursday']
# Length: 5, dtype: str

# %%
order_process_data['Day_name_On_Truck_scan'].value_counts()
# Out:
# Day_name_On_Truck_scan
# Wednesday    3260
# Friday       1377
# Monday       1026
# Tuesday       145
# Thursday       91
# Name: count, dtype: int64

# %%
order_process_data[(order_process_data['Day_name_On_Truck_scan'].isin(['Thursday', 'Tuesday'])) &
    (order_process_data['First_class'] == 0)
]
# Out:
#       Row ID        Order ID Order Date On Truck Scan Date  \
# 128     8383  CA-2019-163048 2019-02-08         2019-02-19
# 129     8842  US-2019-112396 2019-02-09         2019-02-19
# 130     8843  US-2019-112396 2019-02-09         2019-02-19
# 629     3531  US-2019-152835 2019-05-19         2019-05-28
# 630     7467  CA-2019-138282 2019-05-19         2019-05-28
# ...      ...             ...        ...                ...
# 5763    8846  CA-2020-156664 2020-12-18         2020-12-24
# 5764    8847  CA-2020-156664 2020-12-18         2020-12-24
# 5765    8848  CA-2020-156664 2020-12-18         2020-12-24
# 5766    8932  CA-2020-143252 2020-12-18         2020-12-24
# 5767    8933  CA-2020-143252 2020-12-18         2020-12-24
#
#                 Ship Mode  First_class Day_name_On_Truck_scan
# 128   Standard Processing            0                Tuesday
# 129   Standard Processing            0                Tuesday
# 130   Standard Processing            0                Tuesday
# 629   Standard Processing            0                Tuesday
# 630   Standard Processing            0                Tuesday
# ...                   ...          ...                    ...
# 5763  Standard Processing            0               Thursday
# 5764  Standard Processing            0               Thursday
# 5765  Standard Processing            0               Thursday
# 5766  Standard Processing            0               Thursday
# 5767  Standard Processing            0               Thursday
#
# [160 rows x 7 columns]

# %% [markdown]
# | On Truck Scan          | Meaning       |
# | ---------------------- | ------------- |
# | Tue/Thu + No Express   | 🚨 Suspicious |
# | Expected (Mon/Wed/Fri) | ✅ Normal     |

# %%
order_process_data.head(3)
# Out:
#    Row ID        Order ID Order Date On Truck Scan Date            Ship Mode  \
# 0    3074  CA-2019-125206 2019-01-03         2019-01-07              Express
# 1    4919  CA-2019-160304 2019-01-02         2019-01-09  Standard Processing
# 2    4920  CA-2019-160304 2019-01-02         2019-01-09  Standard Processing
#
#    First_class Day_name_On_Truck_scan
# 0            1                 Monday
# 1            0              Wednesday
# 2            0              Wednesday

# %%
order_process_data["Diff_OrderDate_OnTruckScanDate"]=order_process_data["On Truck Scan Date"]-order_process_data["Order Date"]

# %%
order_process_data.head(3)
# Out:
#    Row ID        Order ID Order Date On Truck Scan Date            Ship Mode  \
# 0    3074  CA-2019-125206 2019-01-03         2019-01-07              Express
# 1    4919  CA-2019-160304 2019-01-02         2019-01-09  Standard Processing
# 2    4920  CA-2019-160304 2019-01-02         2019-01-09  Standard Processing
#
#    First_class Day_name_On_Truck_scan Diff_OrderDate_OnTruckScanDate
# 0            1                 Monday                         4 days
# 1            0              Wednesday                         7 days
# 2            0              Wednesday                         7 days

# %%
order_process_data["Diff_OrderDate_OnTruckScanDate"].unique()
# Out:
# <TimedeltaArray>
# [ '4 days',  '7 days',  '6 days',  '5 days',  '1 days',  '9 days',  '8 days',
#   '3 days',  '2 days', '10 days', '11 days',  '0 days', '12 days']
# Length: 13, dtype: timedelta64[us]

# %%
order_process_data.to_excel('../data/cleaned/Clean_order_process_data.xlsx',index=False)
