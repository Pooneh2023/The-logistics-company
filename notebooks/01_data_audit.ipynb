# %%
import pandas as pd

# %%
import numpy as np

# %%
Orders = pd.read_excel('../data/raw/Muesli Project raw data.xlsx',sheet_name='Orders', header = 1)

# %%
Orders.head(5)
# Out:
#    Index        Order ID Order Date       Ship Mode Customer ID  \
# 0     27  CA-2019-121755 2019-01-16    Second Class    EH-13945
# 1     45  CA-2019-118255 2019-03-11     First Class    ON-18715
# 2     48  CA-2019-169194 2019-06-20  Standard Class    LH-16900
# 3     60  CA-2019-111682 2019-06-17     First Class    TB-21055
# 4     63  CA-2018-135545 2018-11-24  Standard Class    KM-16720
#
#      Customer Name Origin Channel Country/Region         City       State  \
# 0    Eric Hoffmann          Email  United States  Los Angeles  California
# 1    Odella Nelson          Sales  United States        Eagan   Minnesota
# 2   Lena Hernandez          Email  United States        Dover    Delaware
# 3  Ted Butterfield          Email  United States         Troy    New York
# 4     Kunst Miller          Email  United States  Los Angeles  California
#
#    Postal Code   Region                 Category Sub-Category  \
# 0      90049.0     West  Special Projects Muesil  Gluten Free
# ...

# %% [markdown]
# #There is a header, but it does not in currect place!

# %%
Orders.columns
# Out:
# Index(['Index', 'Order ID', 'Order Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Origin Channel', 'Country/Region', 'City', 'State',
#        'Postal Code', 'Region', 'Category', 'Sub-Category', 'Product ID',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='str')

# %%
Orders.head(10)
# Out:
#    Index        Order ID Order Date       Ship Mode Customer ID  \
# 0     27  CA-2019-121755 2019-01-16    Second Class    EH-13945
# 1     45  CA-2019-118255 2019-03-11     First Class    ON-18715
# 2     48  CA-2019-169194 2019-06-20  Standard Class    LH-16900
# 3     60  CA-2019-111682 2019-06-17     First Class    TB-21055
# 4     63  CA-2018-135545 2018-11-24  Standard Class    KM-16720
# 5     87  CA-2020-155558 2020-10-26  Standard Class    PG-18895
# 6    101  CA-2019-158568 2019-08-29  Standard Class    RB-19465
# 7    104  US-2018-156867 2018-11-13  Standard Class    LC-16870
# 8    107  CA-2020-119004 2020-11-23  Standard Class    JM-15250
# 9    110  CA-2018-129476 2018-10-15  Standard Class    PA-19060
#
#      Customer Name Origin Channel Country/Region         City           State  \
# 0    Eric Hoffmann          Email  United States  Los Angeles      California
# 1    Odella Nelson          Sales  United States        Eagan       Minnesota
# ...

# %%
Orders.shape
# Out:
# (9994, 19)

# %%
Orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Index           9994 non-null   int64
#  1   Order ID        9994 non-null   str
#  2   Order Date      9994 non-null   datetime64[us]
#  3   Ship Mode       9994 non-null   str
#  4   Customer ID     9994 non-null   str
#  5   Customer Name   9994 non-null   str
#  6   Origin Channel  9994 non-null   str
#  7   Country/Region  9994 non-null   str
#  8   City            9994 non-null   str
#  9   State           9994 non-null   str
#  10  Postal Code     9983 non-null   float64
#  11  Region          9994 non-null   str
#  12  Category        9994 non-null   str
#  13  Sub-Category    9994 non-null   str
#  14  Product ID      9994 non-null   str
#  15  Sales           9994 non-null   float64
#  16  Quantity        9994 non-null   int64
#  17  Discount        9994 non-null   float64
# ...

# %%
Orders.columns
# Out:
# Index(['Index', 'Order ID', 'Order Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Origin Channel', 'Country/Region', 'City', 'State',
#        'Postal Code', 'Region', 'Category', 'Sub-Category', 'Product ID',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='str')

# %%
Orders[['Order ID','Ship Mode', 'Customer ID', 'Origin Channel', 'Country/Region', 'City', 'State','Region', 'Category', 'Sub-Category', 'Product ID']].describe()
# Out:
#               Order ID       Ship Mode Customer ID Origin Channel  \
# count             9994            9994        9994           9994
# unique            5009               3         793              3
# top     CA-2020-100111  Standard Class    WB-21850          Email
# freq                14            5968          37           5191
#
#        Country/Region           City       State Region      Category  \
# count            9994           9994        9994   9994          9994
# unique              1            531          49      4             3
# top     United States  New York City  California   West  Power Muesli
# freq             9994            915        2001   3203          6026
#
#              Sub-Category       Product ID
# count                9994             9994
# unique                 17             1862
# top     Super Fibre Boost  OFF-PA-10001970
# freq                 1523               19

# %%
Orders[['Sales', 'Quantity', 'Discount', 'Profit']].describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
Orders.isna().sum().sort_values(ascending=False)
# Out:
# Postal Code       11
# Index              0
# Discount           0
# Quantity           0
# Sales              0
# Product ID         0
# Sub-Category       0
# Category           0
# Region             0
# State              0
# Order ID           0
# City               0
# Country/Region     0
# Origin Channel     0
# Customer Name      0
# Customer ID        0
# Ship Mode          0
# Order Date         0
# Profit             0
# dtype: int64

# %%
Orders.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 1- there is 11 None value on 'Postal Code' (dealing with missing value)
# 2- No duplicate values
# 3- data type are currect
# 4- check out of line values
# 5- data bining
# 6- turning categorical to numerical

# %%
campaign_date = pd.read_excel('../data/raw/Muesli Project raw data.xlsx',sheet_name='Campaign Data')

# %%
campaign_date.head(10)
# Out:
#          Order ID Arrival Scan Date     Customer Name
# 0  CA-2019-109666        2019-05-03      Kunst Miller
# 1  CA-2019-138933        2019-05-03       Jack Lebron
# 2  CA-2019-130001        2019-05-03  Heather Kirkland
# 3  CA-2019-113061        2019-05-06         Ed Ludwig
# 4  CA-2019-162138        2019-05-06       Grace Kelly
# 5  CA-2019-126270        2019-05-06      Art Ferguson
# 6  CA-2019-168081        2019-05-06   Cathy Armstrong
# 7  CA-2019-149279        2019-05-06      Craig Leslie
# 8  CA-2019-146836        2019-05-06     Cindy Chapman
# 9  CA-2019-109869        2019-05-07     Tanja Norvell

# %%
campaign_date.columns
# Out:
# Index(['Order ID', 'Arrival Scan Date', 'Customer Name'], dtype='str')

# %%
campaign_date.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           333 non-null    str
#  1   Arrival Scan Date  333 non-null    datetime64[us]
#  2   Customer Name      333 non-null    str
# dtypes: datetime64[us](1), str(2)
# memory usage: 7.9 KB

# %%
campaign_date.describe()
# Out:
#                 Arrival Scan Date
# count                         333
# mean   2019-10-14 19:36:12.972973
# min           2019-05-03 00:00:00
# 25%           2019-09-09 00:00:00
# 50%           2019-10-21 00:00:00
# 75%           2019-12-16 00:00:00
# max           2020-05-15 00:00:00

# %%
campaign_date.shape
# Out:
# (333, 3)

# %%
campaign_date.isna().sum().sort_values(ascending=False)
# Out:
# Order ID             0
# Arrival Scan Date    0
# Customer Name        0
# dtype: int64

# %%
campaign_date.duplicated().sum()
# Out:
# np.int64(0)

# %%
order_process_data = pd.read_excel('../data/raw/Muesli Project raw data.xlsx',sheet_name='Order Process Data')

# %%
order_process_data.head()
# Out:
#    Row ID        Order ID Order Date On Truck Scan Date            Ship Mode
# 0    3074  CA-2019-125206 2019-01-03         2019-01-07              Express
# 1    4919  CA-2019-160304 2019-01-02         2019-01-09  Standard Processing
# 2    4920  CA-2019-160304 2019-01-02         2019-01-09  Standard Processing
# 3    8604  US-2019-116365 2019-01-03         2019-01-09  Standard Processing
# 4    8605  US-2019-116365 2019-01-03         2019-01-09  Standard Processing

# %%
order_process_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5899 entries, 0 to 5898
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Row ID              5899 non-null   int64
#  1   Order ID            5899 non-null   str
#  2   Order Date          5899 non-null   datetime64[us]
#  3   On Truck Scan Date  5899 non-null   datetime64[us]
#  4   Ship Mode           5899 non-null   str
# dtypes: datetime64[us](2), int64(1), str(2)
# memory usage: 230.6 KB

# %%
order_process_data.shape
# Out:
# (5899, 5)

# %%
order_process_data.describe(include='all')
# Out:
#              Row ID        Order ID                  Order Date  \
# count   5899.000000            5899                        5899
# unique          NaN            3002                         NaN
# top             NaN  CA-2020-100111                         NaN
# freq            NaN              14                         NaN
# mean    5022.428208             NaN  2020-02-29 02:22:48.231903
# min        1.000000             NaN         2019-01-02 00:00:00
# 25%     2485.500000             NaN         2019-09-11 00:00:00
# 50%     5091.000000             NaN         2020-03-16 00:00:00
# 75%     7460.000000             NaN         2020-09-13 12:00:00
# max     9994.000000             NaN         2020-12-30 00:00:00
# std     2878.464633             NaN                         NaN
#
#                 On Truck Scan Date            Ship Mode
# count                         5899                 5899
# unique                         NaN                    2
# ...

# %%
order_process_data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'On Truck Scan Date', 'Ship Mode'], dtype='str')

# %%
order_process_data.isna().sum().sort_values(ascending=False)
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# On Truck Scan Date    0
# Ship Mode             0
# dtype: int64

# %%
order_process_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
InternData_study = pd.read_excel('../data/raw/Muesli Project raw data.xlsx',sheet_name='InternData Study')

# %%
InternData_study.head()
# Out:
#          Order ID Ready to Ship Date Pickup Date
# 0  CA-2019-116540         2019-09-02  2019-09-03
# 1  CA-2019-116540         2019-09-02  2019-09-03
# 2  CA-2019-129847         2019-09-04  2019-09-04
# 3  CA-2019-129630         2019-09-04  2019-09-04
# 4  CA-2019-106278         2019-09-05  2019-09-06

# %%
InternData_study.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order ID            290 non-null    str
#  1   Ready to Ship Date  290 non-null    datetime64[us]
#  2   Pickup Date         290 non-null    datetime64[us]
# dtypes: datetime64[us](2), str(1)
# memory usage: 6.9 KB

# %%
InternData_study.shape
# Out:
# (290, 3)

# %%
InternData_study.columns
# Out:
# Index(['Order ID', 'Ready to Ship Date', 'Pickup Date'], dtype='str')

# %%
InternData_study.describe()
# Out:
#                Ready to Ship Date                 Pickup Date
# count                         290                         290
# mean   2020-06-18 15:08:41.379310  2020-06-20 06:47:10.344827
# min           2019-09-02 00:00:00         2019-09-03 00:00:00
# 25%           2019-09-23 00:00:00         2019-09-23 12:00:00
# 50%           2020-11-10 00:00:00         2020-11-12 00:00:00
# 75%           2020-11-23 00:00:00         2020-11-23 00:00:00
# max           2020-12-07 00:00:00         2020-12-09 00:00:00

# %%
InternData_study.isna().sum().sort_values(ascending=False)
# Out:
# Order ID              0
# Ready to Ship Date    0
# Pickup Date           0
# dtype: int64

# %%
InternData_study.duplicated().sum()
# Out:
# np.int64(86)

# %% [raw]
# Cleaning data:
#     1- Handling missing data - repititive rows
#     2- Data formating
#     3- data normalization(centering and scaling)
#     4- data binning
#     5- turning categorical to numerical variebles
#
# create new columns belong to our KPIs
