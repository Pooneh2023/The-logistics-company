# %%
import pandas as pd
import numpy as np

# %%
Orders = pd.read_excel('../data/raw/Muesli Project raw data.xlsx',sheet_name='Orders', header = 1)

# %%
Orders.head(2)
# Out:
#    Index        Order ID Order Date     Ship Mode Customer ID  Customer Name  \
# 0     27  CA-2019-121755 2019-01-16  Second Class    EH-13945  Eric Hoffmann
# 1     45  CA-2019-118255 2019-03-11   First Class    ON-18715  Odella Nelson
#
#   Origin Channel Country/Region         City       State  Postal Code  \
# 0          Email  United States  Los Angeles  California      90049.0
# 1          Sales  United States        Eagan   Minnesota      55122.0
#
#     Region                 Category Sub-Category       Product ID  Sales  \
# 0     West  Special Projects Muesil  Gluten Free  TEC-AC-10003027  90.57
# 1  Central  Special Projects Muesil  Gluten Free  TEC-AC-10000171  45.98
#
#    Quantity  Discount   Profit
# 0         3       0.0  11.7741
# 1         2       0.0  19.7714

# %% [markdown]
# 1- there is one None value on 'Postal Code' (dealing with missing value) = there is no matter with missing value in this column!
# 2- check probabitily repititive raws= there is not any repititive value
# 3- data type are currect: checked
# 4- check out of line values
# 5- data bining : days' name
# 6- turning categorical to numerical : Ship Mode

# %%
Orders[Orders['Postal Code'].isna()]
# Out:
#       Index        Order ID Order Date       Ship Mode Customer ID  \
# 173    2235  CA-2020-104066 2020-12-05  Standard Class    QJ-19255
# 710    9147  US-2019-165505 2019-01-23  Standard Class    CB-12535
# 1732   9389  US-2020-127292 2020-01-19  Standard Class    RM-19375
# 3408   9387  US-2020-127292 2020-01-19  Standard Class    RM-19375
# 3409   9388  US-2020-127292 2020-01-19  Standard Class    RM-19375
# 4279   8799  US-2019-150140 2019-04-06  Standard Class    VM-21685
# 4694   9390  US-2020-127292 2020-01-19  Standard Class    RM-19375
# 5490   9149  US-2019-165505 2019-01-23  Standard Class    CB-12535
# 7802   9148  US-2019-165505 2019-01-23  Standard Class    CB-12535
# 8415   9742  CA-2018-117086 2018-11-08  Standard Class    QJ-19255
# 9693   5275  CA-2018-162887 2018-11-07    Second Class    SV-20785
#
#          Customer Name Origin Channel Country/Region        City    State  \
# 173       Quincy Jones          Sales  United States  Burlington  Vermont
# ...

# %%
Orders.isna().count()
# Out:
# Index             9994
# Order ID          9994
# Order Date        9994
# Ship Mode         9994
# Customer ID       9994
# Customer Name     9994
# Origin Channel    9994
# Country/Region    9994
# City              9994
# State             9994
# Postal Code       9994
# Region            9994
# Category          9994
# Sub-Category      9994
# Product ID        9994
# Sales             9994
# Quantity          9994
# Discount          9994
# Profit            9994
# dtype: int64

# %%
Orders[Orders['Postal Code'].isna()].index
# Out:
# Index([173, 710, 1732, 3408, 3409, 4279, 4694, 5490, 7802, 8415, 9693], dtype='int64')

# %%
Orders[Orders['Postal Code'].isna()]
# Out:
#       Index        Order ID Order Date       Ship Mode Customer ID  \
# 173    2235  CA-2020-104066 2020-12-05  Standard Class    QJ-19255
# 710    9147  US-2019-165505 2019-01-23  Standard Class    CB-12535
# 1732   9389  US-2020-127292 2020-01-19  Standard Class    RM-19375
# 3408   9387  US-2020-127292 2020-01-19  Standard Class    RM-19375
# 3409   9388  US-2020-127292 2020-01-19  Standard Class    RM-19375
# 4279   8799  US-2019-150140 2019-04-06  Standard Class    VM-21685
# 4694   9390  US-2020-127292 2020-01-19  Standard Class    RM-19375
# 5490   9149  US-2019-165505 2019-01-23  Standard Class    CB-12535
# 7802   9148  US-2019-165505 2019-01-23  Standard Class    CB-12535
# 8415   9742  CA-2018-117086 2018-11-08  Standard Class    QJ-19255
# 9693   5275  CA-2018-162887 2018-11-07    Second Class    SV-20785
#
#          Customer Name Origin Channel Country/Region        City    State  \
# 173       Quincy Jones          Sales  United States  Burlington  Vermont
# ...

# %%
Orders[Orders['Product ID']=='FUR-BO-10004834']
# Out:
#       Index        Order ID Order Date       Ship Mode Customer ID  \
# 8193     28  US-2018-150630 2018-09-17  Standard Class    TB-21520
# 8201    400  CA-2019-108987 2019-09-08    Second Class    AG-10675
# 8326   5918  US-2018-126977 2018-09-17  Standard Class    PF-19120
# 8369   7815  US-2020-109316 2020-06-08     First Class    MG-17680
# 8415   9742  CA-2018-117086 2018-11-08  Standard Class    QJ-19255
#
#           Customer Name Origin Channel Country/Region           City  \
# 8193    Tracy Blumstein          Email  United States   Philadelphia
# 8201        Anna Gayman          Email  United States        Houston
# 8326       Peter Fuller          Email  United States  New York City
# 8369  Maureen Gastineau       Facebook  United States    Los Angeles
# 8415       Quincy Jones          Sales  United States     Burlington
#
#              State  Postal Code   Region        Category Sub-Category  \
# 8193  Pennsylvania      19140.0     East  Toasted Muesli   With Fruit
# ...

# %%
Orders['Ship Mode'].unique()
# Out:
# <StringArray>
# ['Second Class', 'First Class', 'Standard Class']
# Length: 3, dtype: str

# %%
Orders['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# First Class       2081
# Second Class      1945
# Name: count, dtype: int64

# %%
Orders['First_class']= np.where(
    Orders['Ship Mode']=='First Class', 1 , 0)

# %%
Orders.head(3)
# Out:
#    Index        Order ID Order Date       Ship Mode Customer ID  \
# 0     27  CA-2019-121755 2019-01-16    Second Class    EH-13945
# 1     45  CA-2019-118255 2019-03-11     First Class    ON-18715
# 2     48  CA-2019-169194 2019-06-20  Standard Class    LH-16900
#
#     Customer Name Origin Channel Country/Region         City       State  \
# 0   Eric Hoffmann          Email  United States  Los Angeles  California
# 1   Odella Nelson          Sales  United States        Eagan   Minnesota
# 2  Lena Hernandez          Email  United States        Dover    Delaware
#
#    Postal Code   Region                 Category Sub-Category  \
# 0      90049.0     West  Special Projects Muesil  Gluten Free
# 1      55122.0  Central  Special Projects Muesil  Gluten Free
# 2      19901.0     East  Special Projects Muesil  Gluten Free
#
#         Product ID  Sales  Quantity  Discount   Profit  First_class
# 0  TEC-AC-10003027  90.57         3       0.0  11.7741            0
# ...

# %%
Orders['First_class'].dtypes
# Out:
# dtype('int64')

# %%
Orders['Day_name']=Orders['Order Date'].dt.day_name()

# %%
Orders.head(4)
# Out:
#    Index        Order ID Order Date       Ship Mode Customer ID  \
# 0     27  CA-2019-121755 2019-01-16    Second Class    EH-13945
# 1     45  CA-2019-118255 2019-03-11     First Class    ON-18715
# 2     48  CA-2019-169194 2019-06-20  Standard Class    LH-16900
# 3     60  CA-2019-111682 2019-06-17     First Class    TB-21055
#
#      Customer Name Origin Channel Country/Region         City       State  \
# 0    Eric Hoffmann          Email  United States  Los Angeles  California
# 1    Odella Nelson          Sales  United States        Eagan   Minnesota
# 2   Lena Hernandez          Email  United States        Dover    Delaware
# 3  Ted Butterfield          Email  United States         Troy    New York
#
#    ...   Region                 Category Sub-Category       Product ID  Sales  \
# 0  ...     West  Special Projects Muesil  Gluten Free  TEC-AC-10003027  90.57
# 1  ...  Central  Special Projects Muesil  Gluten Free  TEC-AC-10000171  45.98
# ...

# %%
Orders.tail(5)
# Out:
#       Index        Order ID Order Date       Ship Mode Customer ID  \
# 9989   9894  US-2019-115441 2019-07-25    Second Class    SH-19975
# 9990   9908  US-2018-129007 2018-09-13     First Class    KD-16615
# 9991   9913  CA-2018-132388 2018-10-10     First Class    KN-16390
# 9992   9920  CA-2019-149272 2019-03-15  Standard Class    MY-18295
# 9993   9948  CA-2020-121559 2020-06-01    Second Class    HW-14935
#
#           Customer Name Origin Channel Country/Region           City  \
# 9989      Sally Hughsby          Sales  United States      Milwaukee
# 9990           Ken Dana          Sales  United States        Anaheim
# 9991  Katherine Nockton          Sales  United States  Santa Barbara
# 9992    Muhammed Yedwab          Sales  United States          Bryan
# 9993    Helen Wasserman          Sales  United States   Indianapolis
#
#            State  ...   Region        Category Sub-Category       Product ID  \
# ...

# %%
Clean_Orders_table.to_xlsx('../data/cleaned/Clean_Orders_table.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 Clean_Orders_table.to_xlsx('../data/cleaned/Clean_Orders_table.xlsx')
#
# NameError: name 'Clean_Orders_table' is not defined
